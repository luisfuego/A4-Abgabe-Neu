# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #####
#
# API = Application Programming interface
# REST = Representational Stat Transfer
# REST -Apis werden oft als Reprensentational State Transfer
#
# Schema defieniert von DR. Rox Fielding

# %% [markdown]
# # Abgabe:
# 1. Lege eine Person (z.B. deinen Sitznachbarn) als Testperson im API auf https://datahouse.pythonanywhere.com/api/Testperson/ mit dem Web- Formular an
# 2. Frage diese Person im Ipython Notebook aus dem REST - API mittels GET - REQUEST ab und gib sie mit einem print - Befehl aus
# 3. Analysiere die JSON - Darstellung des API und gib an, a) um welche JSON - Datenstruktur es sich laut https://json.org bei dieser Webseite handelt:
#  ![image.png](attachment:image.png)
#  ![image.png](attachment:image-2.png)
#
#     b) Ergänze einen Screenshot der passenden Datenstrukturen ![image.png](attachment:image-3.png))
#
#     ... und c) begründe (ACHTUNG: es kann sich um eine Kombination mehrerer JSON - Datenstrukturen handeln.)
#
# 4. Lege eine weitere Person mittels post request an und gib die "response" mittels print - Befehl aus
# 5. Führe abschließend einen get - request auf das REST - API aus, erzeuge einen DataFrame aus der zurückgegebenen Liste und gib die ersten 25 Zeilen
# des DataFrame aus. Ergänze dazu als Markdown oder als Kommentar den zutreffenden "Timestamp"
#
# #### Hinweis: Die Teilaufgaben 1 - 5 sollten im Notebook dokumentiert werden. Das Notebook enthält bereits einzelne Code - Bestandteile, die als Hilfestellung verwendet werden können, achte jedoch auf eine nachvollziehbare Struktur!

# %%
#%pip install requests
#%pip install pandas
import requests
import json 
import pandas as pd
url = 'https://datahouse.pythonanywhere.com/api/Testperson/'

# %%
dir(response)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
response = requests.get(url)
print(response)
testdata=response.json()
print(testdata)
print(response.raw)
print(response.text)
print(type(testdata))
print(type(response))
print(response.encoding)
# Out:
# <Response [200]>
# [{'id': 98, 'name': 'SAP', 'alias': 'King', 'rec_time': '2023-04-14T07:24:39.570423Z', 'pers_uuid': 'b0c38abd-2a81-4c6b-a21b-26afc4b5d989'}, {'id': 97, 'name': 'SAP', 'alias': 'King', 'rec_time': '2023-04-14T07:22:54.615726Z', 'pers_uuid': '1d23aa66-c78b-46ee-808f-da1a4a443c08'}, {'id': 96, 'name': 'Fabian', 'alias': 'DF', 'rec_time': '2023-04-14T07:17:57.746626Z', 'pers_uuid': '86b1e350-448f-40f2-a49d-affbfe3939e4'}, {'id': 95, 'name': 'Kajetan', 'alias': 'Daddy', 'rec_time': '2023-04-14T07:17:30.828129Z', 'pers_uuid': '46ef699c-3d1e-4793-b0dd-4d7d1dcfd13b'}, {'id': 94, 'name': 'Rocky', 'alias': 'R', 'rec_
","alias":"Daddy","rec_time":"2023-04-14T07:04:38.188431Z","pers_uuid":"2613895d-4b25-410d-9953-4d2cc3c0c8fe"},{"id":84,"name":"Kajetan","alias":"Daddy","rec_time":"2023-04-14T07:04:24.526009Z","pers_uuid":"e6003fcf-b1c1-4ca8-8c23-52a42b7181ed"},{"id":83,"name":"Florian Simader","alias":"FS","rec_time":"2023-04-14T07:04:12.930922Z","pers_uuid":"627fc000-e29d-4b09-af1b-881e12cb6979"},{"id":82,"name":"Kajetan","alias":"Daddy","rec_time":"2023-04-14T07:02:50.348853Z","pers_uuid":"1f2bb25e-a45d-45be-a29d-59e20ce42d64"},{"id":81,"name":"Denis Rajkovic","alias":"DR","rec_time":"2023-04-14T06:39:55.516451Z","pers_uuid":"9f8e48fb-9f7e-4c04-8aec-9ed1cdbe0415"},{"id":80,"name":"Kilian Klein","alias":"KK","rec_time":"2023-04-14T06:38:44.827455Z","pers_uuid":"daa066fc-30d5-4e4a-9d0f-c5ec66993540"},{"id":79,"name":"Denis Rajkovic","alias":"DR","rec_time":"2023-04-14T06:37:51.731909Z","pers_uuid":"be9b9ab7-6370-453a-b4ae-0a229cbbd7c5"},{"id":78,"name":"Denis Rajkovic","alias":"DR","rec_time":"2023-04-14T06:37:36.580772Z","pers_uuid":"d88cb5c2-ff4a-4c5a-841d-1912059a0bcd"},{"id":77,"name":"Denis Rajkovic","alias":"DR","rec_time":"2023-04-14T06:36:02.394373Z","pers_uuid":"71eca451-b561-4381-a53d-ca04b5ee102b"},{"id":76,"name":"Philip Feitsch","alias":"PF","rec_time":"2023-04-14T06:33:18.683726Z","pers_uuid":"67509b44-ccaf-4127-990d-4b1fa1b62fc0"},{"id":1,"name":"Steve Rogers","alias":"Captain America","rec_time":"2023-03-31T19:43:36.389304Z","pers_uuid":"6741bbc9-181e-484f-b1de-5d3a964aefbc"}]
# <class 'list'>
# <class 'requests.models.Response'>
# utf-8

# %%
type(testdata)
df=pd.DataFrame(testdata)
print(df)
print(df.head(25))
# Out:
#     id             name            alias                     rec_time  \
# 0   98              SAP             King  2023-04-14T07:24:39.570423Z
# 1   97              SAP             King  2023-04-14T07:22:54.615726Z
# 2   96           Fabian               DF  2023-04-14T07:17:57.746626Z
# 3   95          Kajetan            Daddy  2023-04-14T07:17:30.828129Z
# 4   94            Rocky                R  2023-04-14T07:15:41.917952Z
# 5   93      Noah Bodner               NB  2023-04-14T07:15:34.515837Z
# 6   92  Przemyslaw Czak               PC  2023-04-14T07:14:54.910853Z
# 7   91  Przemyslaw Czak               PC  2023-04-14T07:14:44.988379Z
# 8   90      Endlich Pia               EP  2023-04-14T07:14:00.302144Z
# 9   89           Amogus              sus  2023-04-14T07:13:34.909261Z
# 10  88          Kajetan            Daddy  2023-04-14T07:12:46.025449Z
# 11  87          Kajetan            Daddy  2023-04-14T07:06:24.947806Z
# 12  86         Dj Prolo       prolomusic  2023-04-14T07:05:21.571165Z
# 13  85          Kajetan            Daddy  2023-04-14T07:04:38.188431Z
# 12  86         Dj Prolo       prolomusic  2023-04-14T07:05:21.571165Z
# 13  85          Kajetan            Daddy  2023-04-14T07:04:38.188431Z
# 14  84          Kajetan            Daddy  2023-04-14T07:04:24.526009Z
# 15  83  Florian Simader               FS  2023-04-14T07:04:12.930922Z
# 16  82          Kajetan            Daddy  2023-04-14T07:02:50.348853Z
# 17  81   Denis Rajkovic               DR  2023-04-14T06:39:55.516451Z
# 18  80     Kilian Klein               KK  2023-04-14T06:38:44.827455Z
# 19  79   Denis Rajkovic               DR  2023-04-14T06:37:51.731909Z
# 20  78   Denis Rajkovic               DR  2023-04-14T06:37:36.580772Z
# 21  77   Denis Rajkovic               DR  2023-04-14T06:36:02.394373Z
# 22  76   Philip Feitsch               PF  2023-04-14T06:33:18.683726Z
# 23   1     Steve Rogers  Captain America  2023-03-31T19:43:36.389304Z
#
#                                pers_uuid
# 0   b0c38abd-2a81-4c6b-a21b-26afc4b5d989
# 1   1d23aa66-c78b-46ee-808f-da1a4a443c08
# 2   86b1e350-448f-40f2-a49d-affbfe3939e4
# 3   46ef699c-3d1e-4793-b0dd-4d7d1dcfd13b
# 4   86edf803-7039-4869-b418-9b9fa6196850
# 5   a4a42af0-dd19-4e08-b101-d84e56fb7ed6
# 6   72084398-7739-46ae-8955-c799058f5b0d
# 7   a2c686dd-b104-49df-8e84-15bcceb7e2dd
# 8   61163cd9-294d-4fed-9500-275af765814e
# 9   bd9a25d7-7dc8-4c70-9152-288de118493c
# 10  9eea8ff6-6c0f-4422-a8dd-5eab48771ca0
# 11  46b5029d-3ac8-4834-9e95-9d028d40fe71
# 12  c8efb12f-3028-4529-bd83-5184297bb5c8
# 13  2613895d-4b25-410d-9953-4d2cc3c0c8fe
# 14  e6003fcf-b1c1-4ca8-8c23-52a42b7181ed
# 15  627fc000-e29d-4b09-af1b-881e12cb6979
# 16  1f2bb25e-a45d-45be-a29d-59e20ce42d64
# 17  9f8e48fb-9f7e-4c04-8aec-9ed1cdbe0415
# 18  daa066fc-30d5-4e4a-9d0f-c5ec66993540
# 19  be9b9ab7-6370-453a-b4ae-0a229cbbd7c5
# 20  d88cb5c2-ff4a-4c5a-841d-1912059a0bcd
# 21  71eca451-b561-4381-a53d-ca04b5ee102b
# 22  67509b44-ccaf-4127-990d-4b1fa1b62fc0
# 23  6741bbc9-181e-484f-b1de-5d3a964aefbc

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# post request trial 
response1 = requests.post(url,json={
    "name": "Kajetan",
    "alias": "Daddy"
    # ???? another columd is an additional key- value pair
})


print(response1.text)
# Out:
# {"id":115,"name":"Kajetan","alias":"Daddy","rec_time":"2023-04-14T07:40:07.034792Z","pers_uuid":"60dbcd92-3329-4ca9-8861-f495539f7194"}

# %%
response2 = requests.get(url, params={
    "name": "Philip Feitsch",
    "alias" : "PF"
})

print(response2.text)
# Out:
# [{"id":76,"name":"Philip Feitsch","alias":"PF","rec_time":"2023-04-14T06:33:18.683726Z","pers_uuid":"67509b44-ccaf-4127-990d-4b1fa1b62fc0"}]
